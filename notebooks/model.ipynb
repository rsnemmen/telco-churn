# %% [markdown]
# # Preprocessing, modeling and fine-tuning
#
# We want to be able to predict churning.
#
# Ideas for models:
#
# 1. start only with non-spatial features
# 2. if necessary, incorporate location

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import pathlib
from sklearn.model_selection import train_test_split
import nmmn.misc

# %% [markdown]
# ## Import dataset

# %% [markdown]
# ### Read files

# %% [markdown]
# Plans, dependents, charges

# %%
plans=pd.read_excel(pathlib.Path('../data/services.xlsx'))

# %% [markdown]
# Churn reason, category and satisfaction score

# %%
status=pd.read_excel(pathlib.Path('../data/churn_status.xlsx'))

# %% [markdown]
# Location

# %%
loc=pd.read_excel(pathlib.Path('../data/location.xlsx'))

# %% [markdown]
# ### Join
#
# Join all tables into one for convenience

# %%
tmp = pd.merge(plans, status, on='Customer ID', how='inner')  # 'inner' join by default
df = pd.merge(tmp, loc, on='Customer ID', how='inner')

# %% [markdown]
# ## 4. Prepare the data

# %% [markdown]
# When deploying this model for learning purposes, I learned an important lesson:
#
# > One should only keep the "production features" during training.
#
# The issue I had was that when deploying with FastAPI, the model needed all 50 features when in fact it was only trained with less than 10. Keeping only the important features for training is called "train-with-only-what-you-serve".

# %% [markdown]
# ### Train/validation split

# %%
train, val = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# ### Split features and labels

# %% [markdown]
# "Production feature list"

# %%
kept_cols=['Phone Service', 'Online Security', 'Online Backup', 'Premium Tech Support', 'Contract', 
           'Number of Referrals', 'Tenure in Months', 'Monthly Charge']

# %% [markdown]
# Let's separate the labels from the features: `X`=features, `Y`=labels.

# %%
labels=["Churn Value"]
X=train[kept_cols]
Xval=val[kept_cols]
Y=train[labels]
Yval=val[labels]

# %% [markdown]
# ### Pipeline
#
# The idea here in the spirit of scikit-learn is to create a pipeline that performs all necessary transformations on the raw data, be them log, ratios, etc etc. It will also include the standardization for ML training.

# %%
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, StandardScaler, OneHotEncoder

# %%
# Features to keep
binary_categorical_features = ['Phone Service',	'Online Security', 'Online Backup',	'Premium Tech Support']  
multi_class_categorical_features = ['Contract'] 
numerical_features = ['Number of Referrals', 'Tenure in Months', 'Monthly Charge']

# Define preprocessing steps
preprocess = ColumnTransformer([
    ('binary_cat', OneHotEncoder(drop='if_binary'), binary_categorical_features),  # Binary encoded
    ('multi_cat', OneHotEncoder(), multi_class_categorical_features),  # One-hot encoding for multi-class
    ('num', StandardScaler(), numerical_features)  # Scaling for numerical features
], remainder='drop')

# %% [markdown]
# Inspect to see what came out

# %%
preprocess
# Out:
# ColumnTransformer(transformers=[('binary_cat', OneHotEncoder(drop='if_binary'),
#                                  ['Phone Service', 'Online Security',
#                                   'Online Backup', 'Premium Tech Support']),
#                                 ('multi_cat', OneHotEncoder(), ['Contract']),
#                                 ('num', StandardScaler(),
#                                  ['Number of Referrals', 'Tenure in Months',
#                                   'Monthly Charge'])])

# %%
temp=preprocess.fit_transform(X)

# %%
preprocess.get_feature_names_out()
# Out:
# array(['binary_cat__Phone Service_Yes', 'binary_cat__Online Security_Yes',
#        'binary_cat__Online Backup_Yes',
#        'binary_cat__Premium Tech Support_Yes',
#        'multi_cat__Contract_Month-to-Month',
#        'multi_cat__Contract_One Year', 'multi_cat__Contract_Two Year',
#        'num__Number of Referrals', 'num__Tenure in Months',
#        'num__Monthly Charge'], dtype=object)

# %% [markdown]
# # 5. Select and train model

# %%
import nmmn.ml

# %% [markdown]
# ### a. Logistic regression

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Incorporates model into pipeline

# %%
logistic = make_pipeline(preprocess, LogisticRegression(solver='lbfgs') )

# %% [markdown]
# Train the model

# %%
# %%time
logistic.fit(X, Y)
# Out:
# CPU times: user 212 ms, sys: 35.7 ms, total: 248 ms
# Wall time: 56.2 ms
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('binary_cat',
#                                                   OneHotEncoder(drop='if_binary'),
#                                                   ['Phone Service',
#                                                    'Online Security',
#                                                    'Online Backup',
#                                                    'Premium Tech Support']),
#                                                  ('multi_cat', OneHotEncoder(),
#                                                   ['Contract']),
#                                                  ('num', StandardScaler(),
#                                                   ['Number of Referrals',
#                                                    'Tenure in Months',
#                                                    'Monthly Charge'])])),
#                 ('logisticregression', LogisticRegression())])

# %% [markdown]
# #### Accuracy

# %% [markdown]
# Training error

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y, logistic.predict(X))
# Out:
# 0.820021299254526

# %% [markdown]
# Validation error

# %%
accuracy_score(Yval, logistic.predict(Xval))
# Out:
# 0.8147622427253371

# %% [markdown]
# #### Coefficients
#
# Inspect coefficients of logistic regression to understand what are the most important factors driving churn.

# %%
# Access the LogisticRegression model and feature names from the pipeline
logistic_model = logistic.named_steps['logisticregression']
feature_names = logistic.named_steps['columntransformer'].get_feature_names_out() # Assuming you have a ColumnTransformer

# Get the coefficients
coefficients = logistic_model.coef_[0]  # Access the first row (for binary classification)

# Create a DataFrame for better visualization
coef_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})

# Print the DataFrame
coef_df.sort_values(by='Coefficient', ascending=False, key=abs)
# Out:
#                                 Feature  Coefficient
# 6          multi_cat__Contract_Two Year    -1.353316
# 0         binary_cat__Phone Service_Yes    -1.185605
# 9                   num__Monthly Charge     1.164548
# 4    multi_cat__Contract_Month-to-Month     1.025855
# 7              num__Number of Referrals    -0.811669
# 3  binary_cat__Premium Tech Support_Yes    -0.571248
# 8                 num__Tenure in Months    -0.569405
# 1       binary_cat__Online Security_Yes    -0.564855
# 2         binary_cat__Online Backup_Yes    -0.277128
# 5          multi_cat__Contract_One Year    -0.189942

# %% [markdown]
# ### b. Random forest

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier

# %%
forest = make_pipeline(preprocess, RandomForestClassifier(random_state=42))

# %% [markdown]
# Convert `Y` to one column for fitting

# %%
Ytrain1=np.argmax(Y.values, axis=1)
Yval1=np.argmax(Yval.values, axis=1)

# %%
# %%time
# Train the classifier
forest.fit(X, Ytrain1)
# Out:
# CPU times: user 99.8 ms, sys: 4.93 ms, total: 105 ms
# Wall time: 108 ms
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('binary_cat',
#                                                   OneHotEncoder(drop='if_binary'),
#                                                   ['Phone Service',
#                                                    'Online Security',
#                                                    'Online Backup',
#                                                    'Premium Tech Support']),
#                                                  ('multi_cat', OneHotEncoder(),
#                                                   ['Contract']),
#                                                  ('num', StandardScaler(),
#                                                   ['Number of Referrals',
#                                                    'Tenure in Months',
#                                                    'Monthly Charge'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=42))])

# %% [markdown]
# #### Accuracy
#
# Training error

# %%
accuracy_score(Y, forest.predict(X))
# Out:
# 0.7392616258430955

# %% [markdown]
# Validation error

# %%
accuracy_score(Yval, forest.predict(Xval))
# Out:
# 0.71611071682044

# %% [markdown]
# ### c. XGBoost

# %%
from xgboost import XGBClassifier

# %%
# Set up the parameters for the XGBoost model
params = {
    'objective': 'binary:logistic',  
    'max_depth': 6,                # Depth of the trees
    'learning_rate': 0.1,          # Step size shrinkage
    'eval_metric': 'logloss',     
    'seed': 42                     # For reproducibility
}

# %% [markdown]
# #### Train

# %%
gbm = make_pipeline(preprocess, XGBClassifier(**params))#, use_label_encoder=False))

# %%
# %%time
# Train the classifier
gbm.fit(X, Y)
# Out:
# CPU times: user 172 ms, sys: 33.4 ms, total: 206 ms
# Wall time: 77.5 ms
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('binary_cat',
#                                                   OneHotEncoder(drop='if_binary'),
#                                                   ['Phone Service',
#                                                    'Online Security',
#                                                    'Online Backup',
#                                                    'Premium Tech Support']),
#                                                  ('multi_cat', OneHotEncoder(),
#                                                   ['Contract']),
#                                                  ('num', StandardScaler(),
#                                                   ['Number of Referrals',
#                                                    'Tenure in Months',
#                                                    'Monthly Charge'])])),
#                 ('xgbclassifier',
#                  XGBClassifier(base_sc...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=6, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %% [markdown]
# #### Accuracy

# %% [markdown]
# Training error

# %%
accuracy_score(Y, gbm.predict(X))
# Out:
# 0.8718494852680156

# %% [markdown]
# Validation error

# %%
accuracy_score(Yval, gbm.predict(Xval))
# Out:
# 0.829666430092264

# %% [markdown]
# ### Model comparison
#
# #### Accuracy (%)
#
# | Model    | Training | Validation |
# |----------|----------|------------|
# | Random   | 50       |            |
# | Logistic | 82       | 81         |
# | RF       | 74       | 72         |
# | GBM      | 87       | 83         |

# %% [markdown]
# ## 6. Fine-tune
#
# We selected *XGBoost* as the best model. Let's pick the best hyperparameters in a Monte Carlo fashion.

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import RandomizedSearchCV
import scipy.stats
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Hyperparameters

# %%
params = {
    "objective":        "binary:logistic",   # or “multi:softprob”
    "eval_metric":      "logloss",
    "n_jobs":           8,
    "random_state":     42,
}

# %%
tuningPipeline = Pipeline([
    ("preprocess", preprocess),
    ("xgb", XGBClassifier(**params)),
])

# %%
param_distribs = {
    # number of trees
    "xgb__n_estimators":     scipy.stats.randint(100, 1000),
    # step size shrinkage
    "xgb__learning_rate":    scipy.stats.loguniform(1e-3, 1.0),
    # tree depth
    "xgb__max_depth":        scipy.stats.randint(3, 12),
    # minimum sum hessian in leaf
    "xgb__min_child_weight": scipy.stats.randint(1, 10),
    # subsample rows & features
    "xgb__subsample":        scipy.stats.uniform(0.5, 0.5),
    "xgb__colsample_bytree": scipy.stats.uniform(0.5, 0.5),
    # complexity control
    "xgb__gamma":            scipy.stats.loguniform(1e-8, 5.0),
    # L1/L2 regularization
    "xgb__reg_alpha":        scipy.stats.loguniform(1e-8, 1.0),
    "xgb__reg_lambda":       scipy.stats.loguniform(1e-8, 10.0),
}

# %% [markdown]
# ### Number crunching

# %% [markdown]
# Let's try 100 random combinations of hyperparameters: `niter * cv`

# %%
niter=10
cv=10

# %%
search = RandomizedSearchCV(
    tuningPipeline, param_distributions=param_distribs, n_iter=niter, cv=cv,
    scoring='accuracy', random_state=42)

# %%
import warnings
warnings.filterwarnings("ignore", module="sklearn.*") # Suppress warnings from the sklearn module

# %%
# %%time
search.fit(X, Y)
# Out:
# CPU times: user 35.6 s, sys: 1.02 s, total: 36.6 s
# Wall time: 9.21 s
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('preprocess',
#                                               ColumnTransformer(transformers=[('binary_cat',
#                                                                                OneHotEncoder(drop='if_binary'),
#                                                                                ['Phone '
#                                                                                 'Service',
#                                                                                 'Online '
#                                                                                 'Security',
#                                                                                 'Online '
#                                                                                 'Backup',
#                                                                                 'Premium '
#                                                                                 'Tech '
#                                                                                 'Support']),
#                                                                               ('multi_cat',
#                                                                                OneHotEncoder(),
#                                                                                ['Contract']),
#                                                                               ('num',
#                                                                                StandardScaler(),
#                                                                                ['Number '
#                                                                                 'of '
#                                                                                 'Referrals',
#                                                                                 'Tenure '
#                                                                                 'in '
#                                                                                 'Months',
#                                                                                 'Monthly '
#                                                                                 'Cha...
#                                         'xgb__n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x13be20150>,
#                                         'xgb__reg_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x15dc54e10>,
#                                         'xgb__reg_lambda': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x15dc56a90>,
#                                         'xgb__subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x15d5a2990>},
#                    random_state=42, scoring='accuracy')

# %%
res = pd.DataFrame(search.cv_results_)
res.sort_values(by="mean_test_score", ascending=False, inplace=True)
res.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.031100      0.008037         0.004018        0.000498
# 7       0.060349      0.000609         0.003718        0.000342
# 9       0.032161      0.000604         0.003708        0.000073
# 3       0.054754      0.001100         0.004071        0.000139
# 4       0.068582      0.015085         0.004276        0.000276
#
#    param_xgb__colsample_bytree  param_xgb__gamma  param_xgb__learning_rate  \
# 0                     0.687270      1.863096e+00                  0.157030
# 7                     0.760417      2.297241e+00                  0.341666
# 9                     0.599421      1.541496e-02                  0.234707
# 3                     0.683181      9.275538e-05                  0.226740
# 4                     0.585262      3.680288e-08                  0.702517
#
#    param_xgb__max_depth  param_xgb__min_child_weight  param_xgb__n_estimators  \
# 0                     7                            7                      221
# 7                     4                            5                      891
# 9                     7                            7                      140
# 3                     5                            7                      343
# 4                     4                            9                      445
#
#    ...  split3_test_score  split4_test_score  split5_test_score  \
# 0  ...           0.833333           0.834813           0.820604
# 7  ...           0.829787           0.836590           0.808171
# 9  ...           0.831560           0.824156           0.804618
# 3  ...           0.819149           0.829485           0.793961
# 4  ...           0.822695           0.827709           0.783304
#
#   split6_test_score  split7_test_score  split8_test_score  split9_test_score  \
# 0          0.817052           0.822380           0.829485           0.836590
# 7          0.818828           0.836590           0.824156           0.833037
# 9          0.804618           0.813499           0.833037           0.829485
# 3          0.801066           0.817052           0.822380           0.825933
# 4          0.792185           0.806394           0.817052           0.804618
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.826589        0.009317                1
# 7         0.825170        0.011517                2
# 9         0.819665        0.010045                3
# 3         0.814342        0.010530                4
# 4         0.805644        0.014387                5
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Results

# %% [markdown]
# Best hyperparameters

# %%
cols=[6,7,8,24]
res2=res.iloc[:, cols]
res2.head()
# Out:
#    param_xgb__learning_rate  param_xgb__max_depth  \
# 0                  0.157030                     7
# 7                  0.341666                     4
# 9                  0.234707                     7
# 3                  0.226740                     5
# 4                  0.702517                     4
#
#    param_xgb__min_child_weight  mean_test_score
# 0                            7         0.826589
# 7                            5         0.825170
# 9                            7         0.819665
# 3                            7         0.814342
# 4                            9         0.805644

# %% [markdown]
# There is very little room for tuning, so I will not bother.

# %% [raw]
# finalModel = search.best_estimator_  # includes preprocessing

# %% [raw]
# accuracy_score(YtestG, finalModel.predict(Xtest))

# %% [markdown]
# ## 7. Present solution

# %% [markdown]
# Saves model for deployment

# %%
import joblib

# %%
joblib.dump(gbm, "../data/best_model.joblib", compress=3)
# Out:
# ['../data/best_model.joblib']

# %% [markdown]
# ## Sandbox

# %% [markdown]
# Inspect features for Pydantic

# %%
X.shape
# Out:
# (5634, 50)
